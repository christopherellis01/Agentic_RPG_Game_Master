# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from src.state_manager import build_initial_state

from src.models.state_models import (
    CanonicalGameState,
    TransientTurnState,
    SessionExecutionMetadata,
    GameState,
)

# %%
state = GameState(
    canonical=CanonicalGameState(
        current_scene="The village square is tense after news of a missing caravan.",
        location="oakshade_village",
    ),
    turn=TransientTurnState(
        player_action="I ask the innkeeper what she knows about the missing caravan."
    ),
    meta=SessionExecutionMetadata(
        session_id="demo_session_001"
    ),
)

state
# Out:
# GameState(canonical=CanonicalGameState(current_scene='The village square is tense after news of a missing caravan.', location='oakshade_village', active_quests=[], npc_states={}, inventory=[], party_status=PartyStatus(hp=20, max_hp=20, conditions=[], gold=0), recent_events=[]), turn=TransientTurnState(player_action='I ask the innkeeper what she knows about the missing caravan.', selected_route=None, specialist_outputs=[], proposed_updates=[], validation_status='pending', current_turn_events=[], final_response=None), meta=SessionExecutionMetadata(turn_id=1, session_id='demo_session_001', timestamp=None, retry_count=0, max_retries=3))

# %%
state.model_dump()
# Out:
# {'canonical': {'current_scene': 'The village square is tense after news of a missing caravan.',
#   'location': 'oakshade_village',
#   'active_quests': [],
#   'npc_states': {},
#   'inventory': [],
#   'party_status': {'hp': 20, 'max_hp': 20, 'conditions': [], 'gold': 0},
#   'recent_events': []},
#  'turn': {'player_action': 'I ask the innkeeper what she knows about the missing caravan.',
#   'selected_route': None,
#   'specialist_outputs': [],
#   'proposed_updates': [],
#   'validation_status': 'pending',
#   'current_turn_events': [],
#   'final_response': None},
#  'meta': {'turn_id': 1,
#   'session_id': 'demo_session_001',
#   'timestamp': None,
#   'retry_count': 0,
#   'max_retries': 3}}

# %%
import json

print(json.dumps(state.model_dump(), indent=2))
# Out:
# {
#   "canonical": {
#     "current_scene": "The village square is tense after news of a missing caravan.",
#     "location": "oakshade_village",
#     "active_quests": [],
#     "npc_states": {},
#     "inventory": [],
#     "party_status": {
#       "hp": 20,
#       "max_hp": 20,
#       "conditions": [],
#       "gold": 0
#     },
#     "recent_events": []
#   },
#   "turn": {
#     "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#     "selected_route": null,
#     "specialist_outputs": [],
#     "proposed_updates": [],
#     "validation_status": "pending",
#     "current_turn_events": [],
#     "final_response": null
#   },
#   "meta": {
#     "turn_id": 1,
#     "session_id": "demo_session_001",
#     "timestamp": null,
#     "retry_count": 0,
#     "max_retries": 3
#   }
# }

# %%
state.canonical.inventory.append("Torch")
state.canonical.party_status.gold = 15
state.turn.validation_status = "approved"

print(json.dumps(state.model_dump(), indent=2))
# Out:
# {
#   "canonical": {
#     "current_scene": "The village square is tense after news of a missing caravan.",
#     "location": "oakshade_village",
#     "active_quests": [],
#     "npc_states": {},
#     "inventory": [
#       "Torch"
#     ],
#     "party_status": {
#       "hp": 20,
#       "max_hp": 20,
#       "conditions": [],
#       "gold": 15
#     },
#     "recent_events": []
#   },
#   "turn": {
#     "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#     "selected_route": null,
#     "specialist_outputs": [],
#     "proposed_updates": [],
#     "validation_status": "approved",
#     "current_turn_events": [],
#     "final_response": null
#   },
#   "meta": {
#     "turn_id": 1,
#     "session_id": "demo_session_001",
#     "timestamp": null,
#     "retry_count": 0,
#     "max_retries": 3
#   }
# }

# %%
state = build_initial_state(
    session_id="demo_session_001",
    player_action="I walk into the village and look around."
)

state
# Out:
# GameState(canonical=CanonicalGameState(current_scene='The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.', location='Oakshade Village', active_quests=[QuestState(quest_id='missing_caravan', name='The Missing Caravan', status='not_started', objectives=[QuestObjective(objective_id='speak_to_tomas', description='Speak with Tomas Reeve about the missing caravan.', completed=False), QuestObjective(objective_id='investigate_road', description='Investigate the road leading toward Emberwood Ruins.', completed=False), QuestObjective(objective_id='find_caravan', description='Locate the missing caravan or determine what happened to it.', completed=False)], quest_giver_id='tomas_reeve')], npc_states={'marla_innkeeper': NPCState(npc_id='marla_innkeeper', name='Marla Thorn', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['protect the village', 'keep travelers safe']), 'tomas_reeve': NPCState(npc_id='tomas_reeve', name='Tomas Reeve', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['solve the recent disappearances', 'avoid panic'])}, inventory=[], party_status=PartyStatus(hp=20, max_hp=20, conditions=[], gold=0), recent_events=[EventRecord(event_type='session_start', summary='Session initialized in Oakshade Village.', source_node='state_manager')]), turn=TransientTurnState(player_action='I walk into the village and look around.', selected_route=None, specialist_outputs=[], proposed_updates=[], validation_status='pending', current_turn_events=[], final_response=None), meta=SessionExecutionMetadata(turn_id=1, session_id='demo_session_001', timestamp='2026-04-19T21:37:33.294745+00:00', retry_count=0, max_retries=3))

# %%
import json

print(json.dumps(state.model_dump(), indent=2))
# Out:
# {
#   "canonical": {
#     "current_scene": "The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.",
#     "location": "Oakshade Village",
#     "active_quests": [
#       {
#         "quest_id": "missing_caravan",
#         "name": "The Missing Caravan",
#         "status": "not_started",
#         "objectives": [
#           {
#             "objective_id": "speak_to_tomas",
#             "description": "Speak with Tomas Reeve about the missing caravan.",
#             "completed": false
#           },
#           {
#             "objective_id": "investigate_road",
#             "description": "Investigate the road leading toward Emberwood Ruins.",
#             "completed": false
#           },
#           {
#             "objective_id": "find_caravan",
#             "description": "Locate the missing caravan or determine what happened to it.",
#             "completed": false
#           }
#         ],
#         "quest_giver_id": "tomas_reeve"
#       }
#     ],
#     "npc_states": {
#       "marla_innkeeper": {
#         "npc_id": "marla_innkeeper",
#         "name": "Marla Thorn",
#         "location": "oakshade_village",
#         "disposition": "neutral",
#         "last_interaction_summary": null,
#         "known_facts": [],
#         "goals": [
#           "protect the village",
#           "keep travelers safe"
#         ]
#       },
#       "tomas_reeve": {
#         "npc_id": "tomas_reeve",
#         "name": "Tomas Reeve",
#         "location": "oakshade_village",
#         "disposition": "neutral",
#         "last_interaction_summary": null,
#         "known_facts": [],
#         "goals": [
#           "solve the recent disappearances",
#           "avoid panic"
#         ]
#       }
#     },
#     "inventory": [],
#     "party_status": {
#       "hp": 20,
#       "max_hp": 20,
#       "conditions": [],
#       "gold": 0
#     },
#     "recent_events": [
#       {
#         "event_type": "session_start",
#         "summary": "Session initialized in Oakshade Village.",
#         "source_node": "state_manager"
#       }
#     ]
#   },
#   "turn": {
#     "player_action": "I walk into the village and look around.",
#     "selected_route": null,
#     "specialist_outputs": [],
#     "proposed_updates": [],
#     "validation_status": "pending",
#     "current_turn_events": [],
#     "final_response": null
#   },
#   "meta": {
#     "turn_id": 1,
#     "session_id": "demo_session_001",
#     "timestamp": "2026-04-19T21:37:33.294745+00:00",
#     "retry_count": 0,
#     "max_retries": 3
#   }
# }

# %%
from src.state_manager import save_state

save_state(state, Path("../outputs/initial_state.json"))
print("Saved.")
# Out:
# Saved.

# %%
from src.state_manager import load_json, WORLD_PATH, NPC_PATH, QUEST_PATH

print(load_json(WORLD_PATH))
print(load_json(NPC_PATH))
print(load_json(QUEST_PATH))
# Out:
# {'world_name': 'The Shattered Vale', 'tone': 'mysterious, adventurous, lightly dangerous', 'starting_location': 'Oakshade Village', 'locations': [{'id': 'oakshade_village', 'name': 'Oakshade Village', 'description': 'A small forest-edge village with a busy inn, a blacksmith, and anxious townsfolk.'}, {'id': 'emberwood_ruins', 'name': 'Emberwood Ruins', 'description': 'Old stone ruins deep in the woods, rumored to hold relics and restless spirits.'}], 'factions': [{'name': 'Village Council', 'description': 'Local leaders trying to keep Oakshade safe.'}, {'name': 'Ashen Band', 'description': 'A loose group of raiders and scavengers operating near the ruins.'}]}
# {'npcs': [{'id': 'marla_innkeeper', 'name': 'Marla Thorn', 'role': 'Innkeeper', 'location': 'oakshade_village', 'personality': ['warm', 'observant', 'cautious'], 'goals': ['protect the village', 'keep travelers safe'], 'secrets': ['has seen strange lights near the ruins'], 'relationships': {'tomas_reeve': 'trusts', 'player': 'neutral'}}, {'id': 'tomas_reeve', 'name': 'Tomas Reeve', 'role': 'Village Reeve', 'location': 'oakshade_village', 'personality': ['serious', 'dutiful', 'worried'], 'goals': ['solve the recent disappearances', 'avoid panic'], 'secrets': ['suspects the ruins are connected to the missing villagers'], 'relationships': {'marla_innkeeper': 'trusts', 'player': 'neutral'}}]}
# {'quests': [{'id': 'missing_caravan', 'name': 'The Missing Caravan', 'giver': 'tomas_reeve', 'status': 'not_started', 'description': 'A supply caravan vanished on the road near Emberwood Ruins.', 'objectives': [{'id': 'speak_to_tomas', 'description': 'Speak with Tomas Reeve about the missing caravan.', 'completed': False}, {'id': 'investigate_road', 'description': 'Investigate the road leading toward Emberwood Ruins.', 'completed': False}, {'id': 'find_caravan', 'description': 'Locate the missing caravan or determine what happened to it.', 'completed': False}], 'rewards': {'gold': 50, 'item': 'Council Signet'}, 'failure_conditions': ['player_abandons_quest', 'critical_story_npc_dies']}]}

# %%
from src.router import classify_route

state = build_initial_state(
    session_id="demo_session_001",
    player_action="I ask the innkeeper what she knows about the missing caravan."
)

decision = classify_route(state.turn.player_action, state)
decision
# Out:
# RouteDecision(route='mixed_action', next_nodes=['npc_agent', 'quest_agent'], reason='Player action combines conversation with quest-related intent.')

# %%
tests = [
    "I ask the innkeeper what she knows about the missing caravan.",
    "I explore the ruins and search for tracks.",
    "I attack the bandit with my sword.",
    "What do I know about the history of these ruins?",
    "I question Tomas about the quest reward.",
]

for action in tests:
    decision = classify_route(action, state)
    print(action)
    print(decision.model_dump())
    print("-" * 60)
# Out:
# I ask the innkeeper what she knows about the missing caravan.
# {'route': 'mixed_action', 'next_nodes': ['npc_agent', 'quest_agent'], 'reason': 'Player action combines conversation with quest-related intent.'}
# ------------------------------------------------------------
# I explore the ruins and search for tracks.
# {'route': 'exploration', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to focus on movement, searching, or environment interaction.'}
# ------------------------------------------------------------
# I attack the bandit with my sword.
# {'route': 'combat', 'next_nodes': ['rules_agent'], 'reason': 'Player action contains combat-oriented language.'}
# ------------------------------------------------------------
# What do I know about the history of these ruins?
# {'route': 'lore_query', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to request world or setting knowledge.'}
# ------------------------------------------------------------
# I question Tomas about the quest reward.
# {'route': 'mixed_action', 'next_nodes': ['npc_agent', 'quest_agent'], 'reason': 'Player action combines conversation with quest-related intent.'}
# ------------------------------------------------------------

# %%
extra_tests = [
    "I go north.",
    "I talk to Marla.",
    "I inspect the wagon.",
    "I defend myself from the wolf.",
    "Tell me about the Ashen Band.",
    "I report back to Tomas.",
]

for action in extra_tests:
    decision = classify_route(action, state)
    print(action)
    print(decision.model_dump())
    print("-" * 60)
# Out:
# I go north.
# {'route': 'exploration', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to focus on movement, searching, or environment interaction.'}
# ------------------------------------------------------------
# I talk to Marla.
# {'route': 'dialogue', 'next_nodes': ['npc_agent'], 'reason': 'Player action appears to be directed at a character or conversation.'}
# ------------------------------------------------------------
# I inspect the wagon.
# {'route': 'exploration', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to focus on movement, searching, or environment interaction.'}
# ------------------------------------------------------------
# I defend myself from the wolf.
# {'route': 'combat', 'next_nodes': ['rules_agent'], 'reason': 'Player action contains combat-oriented language.'}
# ------------------------------------------------------------
# Tell me about the Ashen Band.
# {'route': 'dialogue', 'next_nodes': ['npc_agent'], 'reason': 'Player action appears to be directed at a character or conversation.'}
# ------------------------------------------------------------
# I report back to Tomas.
# {'route': 'quest_progression', 'next_nodes': ['quest_agent'], 'reason': 'Player action appears tied to a quest objective or mission progress.'}
# ------------------------------------------------------------

# %%
from src.state_manager import build_initial_state
from src.orchestrator import run_turn

# %%
state = build_initial_state(
    session_id="demo_session_001",
    player_action="The player enters the world."
)

# %%
result = run_turn(
    state,
    "I ask the innkeeper what she knows about the missing caravan."
)

result
# Out:
# OrchestrationResult(player_action='I ask the innkeeper what she knows about the missing caravan.', selected_route='mixed_action', next_nodes=['npc_agent', 'quest_agent'], execution_plan=['npc_agent', 'quest_agent'], execution_results=[NodeExecutionResult(node_name='npc_agent', status='completed', summary='Placeholder execution completed for npc_agent.', attempts=1), NodeExecutionResult(node_name='quest_agent', status='completed', summary='Placeholder execution completed for quest_agent.', attempts=1)], reason='Player action combines conversation with quest-related intent.', aborted=False, abort_reason=None, state=GameState(canonical=CanonicalGameState(current_scene='The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.', location='Oakshade Village', active_quests=[QuestState(quest_id='missing_caravan', name='The Missing Caravan', status='not_started', objectives=[QuestObjective(objective_id='speak_to_tomas', description='Speak with Tomas Reeve about the missing caravan.', completed=False), QuestObjective(objective_id='investigate_road', description='Investigate the road leading toward Emberwood Ruins.', completed=False), QuestObjective(objective_id='find_caravan', description='Locate the missing caravan or determine what happened to it.', completed=False)], quest_giver_id='tomas_reeve')], npc_states={'marla_innkeeper': NPCState(npc_id='marla_innkeeper', name='Marla Thorn', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['protect the village', 'keep travelers safe']), 'tomas_reeve': NPCState(npc_id='tomas_reeve', name='Tomas Reeve', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['solve the recent disappearances', 'avoid panic'])}, inventory=[], party_status=PartyStatus(hp=20, max_hp=20, conditions=[], gold=0), recent_events=[EventRecord(event_type='session_start', summary='Session initialized in Oakshade Village.', source_node='state_manager')]), turn=TransientTurnState(player_action='I ask the innkeeper what she knows about the missing caravan.', selected_route='mixed_action', specialist_outputs=[], proposed_updates=[], validation_status='pending', current_turn_events=[EventRecord(event_type='route_selected', summary="Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].", source_node='orchestrator'), EventRecord(event_type='route_reason', summary='Player action combines conversation with quest-related intent.', source_node='router'), EventRecord(event_type='execution_plan_built', summary="Execution plan created: ['npc_agent', 'quest_agent']", source_node='orchestrator'), EventRecord(event_type='node_executed', summary='npc_agent executed with placeholder behavior.', source_node='orchestrator'), EventRecord(event_type='node_executed', summary='quest_agent executed with placeholder behavior.', source_node='orchestrator')], final_response=None), meta=SessionExecutionMetadata(turn_id=2, session_id='demo_session_001', timestamp='2026-04-19T21:37:35.168722+00:00', retry_count=0, max_retries=3)))

# %%
import json
print(json.dumps(result.model_dump(), indent=2))
# Out:
# {
#   "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#   "selected_route": "mixed_action",
#   "next_nodes": [
#     "npc_agent",
#     "quest_agent"
#   ],
#   "execution_plan": [
#     "npc_agent",
#     "quest_agent"
#   ],
#   "execution_results": [
#     {
#       "node_name": "npc_agent",
#       "status": "completed",
#       "summary": "Placeholder execution completed for npc_agent.",
#       "attempts": 1
#     },
#     {
#       "node_name": "quest_agent",
#       "status": "completed",
#       "summary": "Placeholder execution completed for quest_agent.",
#       "attempts": 1
#     }
#   ],
#   "reason": "Player action combines conversation with quest-related intent.",
#   "aborted": false,
#   "abort_reason": null,
#   "state": {
#     "canonical": {
#       "current_scene": "The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.",
#       "location": "Oakshade Village",
#       "active_quests": [
#         {
#           "quest_id": "missing_caravan",
#           "name": "The Missing Caravan",
#           "status": "not_started",
#           "objectives": [
#             {
#               "objective_id": "speak_to_tomas",
#               "description": "Speak with Tomas Reeve about the missing caravan.",
#               "completed": false
#             },
#             {
#               "objective_id": "investigate_road",
#               "description": "Investigate the road leading toward Emberwood Ruins.",
#               "completed": false
#             },
#             {
#               "objective_id": "find_caravan",
#               "description": "Locate the missing caravan or determine what happened to it.",
#               "completed": false
#             }
#           ],
#           "quest_giver_id": "tomas_reeve"
#         }
#       ],
#       "npc_states": {
#         "marla_innkeeper": {
#           "npc_id": "marla_innkeeper",
#           "name": "Marla Thorn",
#           "location": "oakshade_village",
#           "disposition": "neutral",
#           "last_interaction_summary": null,
#           "known_facts": [],
#           "goals": [
#             "protect the village",
#             "keep travelers safe"
#           ]
#         },
#         "tomas_reeve": {
#           "npc_id": "tomas_reeve",
#           "name": "Tomas Reeve",
#           "location": "oakshade_village",
#           "disposition": "neutral",
#           "last_interaction_summary": null,
#           "known_facts": [],
#           "goals": [
#             "solve the recent disappearances",
#             "avoid panic"
#           ]
#         }
#       },
#       "inventory": [],
#       "party_status": {
#         "hp": 20,
#         "max_hp": 20,
#         "conditions": [],
#         "gold": 0
#       },
#       "recent_events": [
#         {
#           "event_type": "session_start",
#           "summary": "Session initialized in Oakshade Village.",
#           "source_node": "state_manager"
#         }
#       ]
#     },
#     "turn": {
#       "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#       "selected_route": "mixed_action",
#       "specialist_outputs": [],
#       "proposed_updates": [],
#       "validation_status": "pending",
#       "current_turn_events": [
#         {
#           "event_type": "route_selected",
#           "summary": "Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].",
#           "source_node": "orchestrator"
#         },
#         {
#           "event_type": "route_reason",
#           "summary": "Player action combines conversation with quest-related intent.",
#           "source_node": "router"
#         },
#         {
#           "event_type": "execution_plan_built",
#           "summary": "Execution plan created: ['npc_agent', 'quest_agent']",
#           "source_node": "orchestrator"
#         },
#         {
#           "event_type": "node_executed",
#           "summary": "npc_agent executed with placeholder behavior.",
#           "source_node": "orchestrator"
#         },
#         {
#           "event_type": "node_executed",
#           "summary": "quest_agent executed with placeholder behavior.",
#           "source_node": "orchestrator"
#         }
#       ],
#       "final_response": null
#     },
#     "meta": {
#       "turn_id": 2,
#       "session_id": "demo_session_001",
#       "timestamp": "2026-04-19T21:37:35.168722+00:00",
#       "retry_count": 0,
#       "max_retries": 3
#     }
#   }
# }

# %%
print("Selected route:", result.selected_route)
print("Execution plan:", result.execution_plan)

for item in result.execution_results:
    print(item.model_dump())
# Out:
# Selected route: mixed_action
# Execution plan: ['npc_agent', 'quest_agent']
# {'node_name': 'npc_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for npc_agent.', 'attempts': 1}
# {'node_name': 'quest_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for quest_agent.', 'attempts': 1}

# %%
for event in result.state.turn.current_turn_events:
    print(event.model_dump())
# Out:
# {'event_type': 'route_selected', 'summary': "Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].", 'source_node': 'orchestrator'}
# {'event_type': 'route_reason', 'summary': 'Player action combines conversation with quest-related intent.', 'source_node': 'router'}
# {'event_type': 'execution_plan_built', 'summary': "Execution plan created: ['npc_agent', 'quest_agent']", 'source_node': 'orchestrator'}
# {'event_type': 'node_executed', 'summary': 'npc_agent executed with placeholder behavior.', 'source_node': 'orchestrator'}
# {'event_type': 'node_executed', 'summary': 'quest_agent executed with placeholder behavior.', 'source_node': 'orchestrator'}

# %%
from src.orchestrator import run_turn

state = build_initial_state(session_id="demo_session_001")

result = run_turn(
    state,
    "I ask the innkeeper what she knows about the missing caravan."
)

print("Aborted:", result.aborted)
print("Abort reason:", result.abort_reason)
for item in result.execution_results:
    print(item.model_dump())
# Out:
# Aborted: False
# Abort reason: None
# {'node_name': 'npc_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for npc_agent.', 'attempts': 1}
# {'node_name': 'quest_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for quest_agent.', 'attempts': 1}

# %%
state = build_initial_state(session_id="demo_session_002")

failed_result = run_turn(
    state,
    "I ask the innkeeper what she knows about the missing caravan.",
    fail_nodes=["npc_agent"]
)

print("Aborted:", failed_result.aborted)
print("Abort reason:", failed_result.abort_reason)
for item in failed_result.execution_results:
    print(item.model_dump())
# Out:
# Aborted: True
# Abort reason: npc_agent exceeded max retries (3).
# {'node_name': 'npc_agent', 'status': 'failed', 'summary': 'npc_agent failed after 3 retries. Execution aborted.', 'attempts': 3}

# %%
for event in failed_result.state.turn.current_turn_events:
    print(event.model_dump())
# Out:
# {'event_type': 'route_selected', 'summary': "Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].", 'source_node': 'orchestrator'}
# {'event_type': 'route_reason', 'summary': 'Player action combines conversation with quest-related intent.', 'source_node': 'router'}
# {'event_type': 'execution_plan_built', 'summary': "Execution plan created: ['npc_agent', 'quest_agent']", 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 1. Retry count is now 1.', 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 2. Retry count is now 2.', 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 3. Retry count is now 3.', 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 4. Retry count is now 4.', 'source_node': 'orchestrator'}
# {'event_type': 'execution_aborted', 'summary': 'npc_agent exceeded max retries (3).', 'source_node': 'orchestrator'}

# %%
from src.agents.lore_agent import LoreAgentInput, run_lore_agent
from src.agents.npc_agent import NPCAgentInput, run_npc_agent

# %%
lore_input = LoreAgentInput(
    player_action="I explore the ruins and search for tracks.",
    current_scene="The player stands at the edge of Emberwood Ruins near broken stone walls.",
    location="Emberwood Ruins",
    world_summary="The Shattered Vale is an old frontier region filled with ruined sites, local rumors, and small settlements trying to survive.",
    relevant_facts=[
        "The Emberwood Ruins are rumored to be tied to recent disappearances.",
        "The village believes strange lights have been seen near the ruins at night.",
    ],
    active_quest_summaries=[
        "The Missing Caravan: investigate what happened near the ruins."
    ],
)

npc_input = NPCAgentInput(
    player_action="I ask the innkeeper what she knows about the missing caravan.",
    npc_name="Marla Thorn",
    npc_role="Innkeeper",
    npc_personality=["warm", "observant", "cautious"],
    npc_goals=["protect the village", "keep travelers safe"],
    npc_disposition="neutral",
    current_scene="The player is speaking with Marla inside the village inn.",
    relationship_summary="Marla does not know the player well yet.",
    relevant_memory=[
        "Marla has seen strange lights near the ruins.",
        "She is worried the missing caravan may mean trouble is getting closer to the village.",
    ],
)

# %%
lore_result = await run_lore_agent(lore_input)
npc_result = await run_npc_agent(npc_input)

print(lore_result.model_dump())
print(npc_result.model_dump())
# Out:
# {'summary': 'The player explores the Emberwood Ruins and searches for tracks. Given the site\'s connection to recent disappearances and the Missing Caravan quest, this is a high-value investigative action. The ruins are old frontier stonework — crumbled walls, overgrown foundations, and loose rubble — terrain that would preserve tracks poorly in some spots but well in others (soft earth near collapsed interiors, ash or soot deposits consistent with the "Emberwood" name). A careful search would likely surface physical evidence of recent human or creature activity consistent with the caravan\'s passage or struggle.', 'environmental_details': ['Broken stone walls provide partial cover and create blind spots throughout the ruin layout — movement through the site would naturally funnel along certain paths.', 'Soft earth and ash deposits between the stone sections are likely to hold boot prints, drag marks, or animal tracks.', 'Overgrown vegetation (vines, scrub brush) may be disturbed or trampled near recent points of entry.', "The 'Ember' prefix suggests the site may have a history of fire — scorched stone or old burn marks could be present, and any new scorch marks would stand out.", 'Nighttime light sources (as reported by villagers) could leave behind residue: wax drippings, oil stains, char marks from torches, or unexplained luminescent residue if the source is unnatural.'], 'lore_facts_used': ['Emberwood Ruins are rumored to be tied to recent disappearances in the region.', 'Strange lights have been seen near the ruins at night by village witnesses.', 'The Missing Caravan quest directs the player to investigate what happened near the ruins.', 'The Shattered Vale is described as an old frontier region with ruined sites — implying weathered, partially overgrown terrain typical of long-abandoned settlements.'], 'proposed_consequences': ['Player discovers wagon wheel ruts or heavy boot tracks leading deeper into the ruins, consistent with a caravan having entered recently.', 'Tracks show signs of sudden stopping or scattering — suggesting the caravan party was surprised or fled in multiple directions.', 'Evidence of a campfire or light source (torch sconce, oil-stained ground) is found in a sheltered interior section, hinting at deliberate nighttime occupation of the ruins.', 'Drag marks in the soft earth suggest something — or someone — was moved from one location to another within the ruins, raising the stakes of the disappearance.', 'Animal tracks (possibly large predator or unknown creature) are interspersed with the human tracks, suggesting the caravan may have encountered something hostile.', 'No tracks lead back out of the ruins along the main approach, implying whatever entered did not leave the same way — or did not leave at all.'], 'suggested_next_step': 'Follow the tracks deeper into the ruins toward the interior section where light sources appear to have been used — likely the focal point of recent activity and potentially where caravan members or their fate can be discovered.'}
# {'speech': '*Marla pauses mid-wipe of the bar counter, glancing toward the door before meeting your eyes.* "That caravan... aye, I\'ve been thinking on it more than I\'d like to admit. Jorren\'s crew was due three days ago — never late, not once in six years." *She lowers her voice, leaning slightly over the counter.* "I don\'t know what happened to them, and I won\'t pretend otherwise. But I\'ll tell you what I *have* seen — lights, out near the old ruins east of the road. Flickering, strange-colored. Twice now, after midnight." *She straightens and resumes wiping the counter, slower this time, more deliberate.* "I haven\'t told the whole village yet. Don\'t want a panic. But if you\'re heading out that way... well. You\'d do well to be careful, and I\'d do well to know someone with a steady head is looking into it."', 'emotional_tone': "Concerned and guarded, but cautiously hopeful. Marla is worried and carrying the weight of this knowledge alone. She's sizing the player up — not quite trusting yet, but willing to extend a careful hand.", 'intent': "Marla wants to share what she knows without causing village-wide panic. She is quietly testing whether the player is trustworthy and competent enough to act on this information responsibly. She's also subtly asking for help without directly requesting it — consistent with her cautious, protective nature.", 'proposed_social_consequences': ["If the player responds with calm reassurance or a protective attitude, Marla's disposition may shift from Neutral toward Friendly, unlocking more detailed information or personal favors.", 'If the player reacts with alarm, loudly shares the information, or seems reckless, Marla may become Guarded and withhold further details to prevent panic.', 'If the player asks thoughtful follow-up questions, Marla may volunteer the exact location of the lights or mention a local she suspects might know more.', "Marla quietly noting the player's reaction could seed a reputation effect — she is well-connected in the village and her opinion of the player may influence how other villagers treat them."], 'suggested_next_step': "The player could ask about the lights near the ruins, press for more details about Jorren's caravan or route, ask Marla to keep this quiet, or offer reassurance — each path will shape how much Marla opens up."}
