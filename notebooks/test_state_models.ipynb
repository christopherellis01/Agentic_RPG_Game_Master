# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from src.state_manager import build_initial_state

from src.models.state_models import (
    CanonicalGameState,
    TransientTurnState,
    SessionExecutionMetadata,
    GameState,
)

# %%
state = GameState(
    canonical=CanonicalGameState(
        current_scene="The village square is tense after news of a missing caravan.",
        location="oakshade_village",
    ),
    turn=TransientTurnState(
        player_action="I ask the innkeeper what she knows about the missing caravan."
    ),
    meta=SessionExecutionMetadata(
        session_id="demo_session_001"
    ),
)

state
# Out:
# GameState(canonical=CanonicalGameState(current_scene='The village square is tense after news of a missing caravan.', location='oakshade_village', active_quests=[], npc_states={}, inventory=[], party_status=PartyStatus(hp=20, max_hp=20, conditions=[], gold=0), recent_events=[]), turn=TransientTurnState(player_action='I ask the innkeeper what she knows about the missing caravan.', selected_route=None, specialist_outputs=[], proposed_updates=[], validation_status='pending', current_turn_events=[], final_response=None), meta=SessionExecutionMetadata(turn_id=1, session_id='demo_session_001', timestamp=None, retry_count=0, max_retries=3))

# %%
state.model_dump()
# Out:
# {'canonical': {'current_scene': 'The village square is tense after news of a missing caravan.',
#   'location': 'oakshade_village',
#   'active_quests': [],
#   'npc_states': {},
#   'inventory': [],
#   'party_status': {'hp': 20, 'max_hp': 20, 'conditions': [], 'gold': 0},
#   'recent_events': []},
#  'turn': {'player_action': 'I ask the innkeeper what she knows about the missing caravan.',
#   'selected_route': None,
#   'specialist_outputs': [],
#   'proposed_updates': [],
#   'validation_status': 'pending',
#   'current_turn_events': [],
#   'final_response': None},
#  'meta': {'turn_id': 1,
#   'session_id': 'demo_session_001',
#   'timestamp': None,
#   'retry_count': 0,
#   'max_retries': 3}}

# %%
import json

print(json.dumps(state.model_dump(), indent=2))
# Out:
# {
#   "canonical": {
#     "current_scene": "The village square is tense after news of a missing caravan.",
#     "location": "oakshade_village",
#     "active_quests": [],
#     "npc_states": {},
#     "inventory": [],
#     "party_status": {
#       "hp": 20,
#       "max_hp": 20,
#       "conditions": [],
#       "gold": 0
#     },
#     "recent_events": []
#   },
#   "turn": {
#     "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#     "selected_route": null,
#     "specialist_outputs": [],
#     "proposed_updates": [],
#     "validation_status": "pending",
#     "current_turn_events": [],
#     "final_response": null
#   },
#   "meta": {
#     "turn_id": 1,
#     "session_id": "demo_session_001",
#     "timestamp": null,
#     "retry_count": 0,
#     "max_retries": 3
#   }
# }

# %%
state.canonical.inventory.append("Torch")
state.canonical.party_status.gold = 15
state.turn.validation_status = "approved"

print(json.dumps(state.model_dump(), indent=2))
# Out:
# {
#   "canonical": {
#     "current_scene": "The village square is tense after news of a missing caravan.",
#     "location": "oakshade_village",
#     "active_quests": [],
#     "npc_states": {},
#     "inventory": [
#       "Torch"
#     ],
#     "party_status": {
#       "hp": 20,
#       "max_hp": 20,
#       "conditions": [],
#       "gold": 15
#     },
#     "recent_events": []
#   },
#   "turn": {
#     "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#     "selected_route": null,
#     "specialist_outputs": [],
#     "proposed_updates": [],
#     "validation_status": "approved",
#     "current_turn_events": [],
#     "final_response": null
#   },
#   "meta": {
#     "turn_id": 1,
#     "session_id": "demo_session_001",
#     "timestamp": null,
#     "retry_count": 0,
#     "max_retries": 3
#   }
# }

# %%
state = build_initial_state(
    session_id="demo_session_001",
    player_action="I walk into the village and look around."
)

state
# Out:
# GameState(canonical=CanonicalGameState(current_scene='The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.', location='Oakshade Village', active_quests=[QuestState(quest_id='missing_scout', name='The Missing Scout', status='not_started', objectives=[QuestObjective(objective_id='speak_to_mara', description='Speak with Mara at the inn and agree to help look into the missing scout.', completed=False), QuestObjective(objective_id='gather_information', description="Gather information about the Ashen Band or the scout's route from villagers or travelers.", completed=False), QuestObjective(objective_id='search_emberwood_ruins', description="Travel to the Emberwood Ruins and search for evidence of the scout's fate.", completed=False)], quest_giver_id='mara_innkeeper')], npc_states={'mara_innkeeper': NPCState(npc_id='mara_innkeeper', name='Mara', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=["Keep Oakshade's travelers safe and paying", 'Find out what is happening near the Emberwood Ruins', 'Avoid open conflict with the Ashen Band while the Council figures out what to do']), 'corvin_stranger': NPCState(npc_id='corvin_stranger', name='Corvin', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['Find out what the Ashen Band is pulling out of the Emberwood Ruins', 'Avoid being identified by the Village Council', 'Recruit an outsider to do the dangerous part of his investigation']), 'harlan_smith': NPCState(npc_id='harlan_smith', name='Harlan', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['Keep his forge running through a bad season', 'Avoid being blamed for buying metal that might have come from the ruins', 'Protect his family from anything that looks like Ashen Band trouble'])}, inventory=[], party_status=PartyStatus(hp=20, max_hp=20, conditions=[], gold=0), recent_events=[EventRecord(event_type='session_start', summary='Session initialized in Oakshade Village.', source_node='state_manager')]), turn=TransientTurnState(player_action='I walk into the village and look around.', selected_route=None, specialist_outputs=[], proposed_updates=[], validation_status='pending', current_turn_events=[], final_response=None), meta=SessionExecutionMetadata(turn_id=1, session_id='demo_session_001', timestamp='2026-04-24T16:39:09.729031+00:00', retry_count=0, max_retries=3))

# %%
import json

print(json.dumps(state.model_dump(), indent=2))
# Out:
# {
#   "canonical": {
#     "current_scene": "The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.",
#     "location": "Oakshade Village",
#     "active_quests": [
#       {
#         "quest_id": "missing_scout",
#         "name": "The Missing Scout",
#         "status": "not_started",
#         "objectives": [
#           {
#             "objective_id": "speak_to_mara",
#             "description": "Speak with Mara at the inn and agree to help look into the missing scout.",
#             "completed": false
#           },
#           {
#             "objective_id": "gather_information",
#             "description": "Gather information about the Ashen Band or the scout's route from villagers or travelers.",
#             "completed": false
#           },
#           {
#             "objective_id": "search_emberwood_ruins",
#             "description": "Travel to the Emberwood Ruins and search for evidence of the scout's fate.",
#             "completed": false
#           }
#         ],
#         "quest_giver_id": "mara_innkeeper"
#       }
#     ],
#     "npc_states": {
#       "mara_innkeeper": {
#         "npc_id": "mara_innkeeper",
#         "name": "Mara",
#         "location": "oakshade_village",
#         "disposition": "neutral",
#         "last_interaction_summary": null,
#         "known_facts": [],
#         "goals": [
#           "Keep Oakshade's travelers safe and paying",
#           "Find out what is happening near the Emberwood Ruins",
#           "Avoid open conflict with the Ashen Band while the Council figures out what to do"
#         ]
#       },
#       "corvin_stranger": {
#         "npc_id": "corvin_stranger",
#         "name": "Corvin",
#         "location": "oakshade_village",
#         "disposition": "neutral",
#         "last_interaction_summary": null,
#         "known_facts": [],
#         "goals": [
#           "Find out what the Ashen Band is pulling out of the Emberwood Ruins",
#           "Avoid being identified by the Village Council",
#           "Recruit an outsider to do the dangerous part of his investigation"
#         ]
#       },
#       "harlan_smith": {
#         "npc_id": "harlan_smith",
#         "name": "Harlan",
#         "location": "oakshade_village",
#         "disposition": "neutral",
#         "last_interaction_summary": null,
#         "known_facts": [],
#         "goals": [
#           "Keep his forge running through a bad season",
#           "Avoid being blamed for buying metal that might have come from the ruins",
#           "Protect his family from anything that looks like Ashen Band trouble"
#         ]
#       }
#     },
#     "inventory": [],
#     "party_status": {
#       "hp": 20,
#       "max_hp": 20,
#       "conditions": [],
#       "gold": 0
#     },
#     "recent_events": [
#       {
#         "event_type": "session_start",
#         "summary": "Session initialized in Oakshade Village.",
#         "source_node": "state_manager"
#       }
#     ]
#   },
#   "turn": {
#     "player_action": "I walk into the village and look around.",
#     "selected_route": null,
#     "specialist_outputs": [],
#     "proposed_updates": [],
#     "validation_status": "pending",
#     "current_turn_events": [],
#     "final_response": null
#   },
#   "meta": {
#     "turn_id": 1,
#     "session_id": "demo_session_001",
#     "timestamp": "2026-04-24T16:39:09.729031+00:00",
#     "retry_count": 0,
#     "max_retries": 3
#   }
# }

# %%
from src.state_manager import save_state

save_state(state, Path("../outputs/initial_state.json"))
print("Saved.")
# Out:
# Saved.

# %%
from src.state_manager import load_json, WORLD_PATH, NPC_PATH, QUEST_PATH

print(load_json(WORLD_PATH))
print(load_json(NPC_PATH))
print(load_json(QUEST_PATH))
# Out:
# {'world_name': 'The Shattered Vale', 'tone': 'mysterious, adventurous, lightly dangerous', 'starting_location': 'Oakshade Village', 'world_summary': "The Shattered Vale is a patchwork of forest-edge villages and ruined holdfasts left behind by a fallen kingdom. Travel between settlements is slow and uncertain, and the Vale's old stone ruins hum with restless things that the living do not fully understand. Oakshade sits at the southern edge of the wood, the last ordered place before the trees grow wild.", 'locations': [{'id': 'oakshade_village', 'name': 'Oakshade Village', 'description': 'A small forest-edge village with a busy inn, a blacksmith, and anxious townsfolk.', 'environmental_details': ["The inn's common room is warm and loud, with travelers crowded close to the hearth.", "A blacksmith's hammer rings from a forge near the village gate.", 'Villagers glance at strangers longer than feels comfortable.', 'A hand-painted sign at the gate warns travelers to be clear of the woods by nightfall.'], 'notable_features': ["The inn, which doubles as the village's informal meeting hall.", 'A small shrine at the center of the square, recently tended.', 'A bulletin board near the blacksmith with notices of missing travelers and posted bounties.'], 'relevant_facts': ['Several villagers have gone missing near the Emberwood Ruins in the past season.', 'The Village Council governs Oakshade and is openly worried about the Ashen Band.', 'Outsiders are tolerated but watched; the innkeeper is the first person most strangers speak to.', 'The woods between Oakshade and the ruins are considered safe by day and dangerous by night.'], 'active_rumors': ['A scout from the Village Council has not returned from a trip toward the ruins.', 'Ashen Band raiders have been seen carrying items that do not look like normal loot.', 'Lights have been seen moving through the ruins after dark, though no fires are ever found.']}, {'id': 'emberwood_ruins', 'name': 'Emberwood Ruins', 'description': 'Old stone ruins deep in the woods, rumored to hold relics and restless spirits.', 'environmental_details': ['Cracked stone walls rise out of moss and tangled roots.', 'Carvings on the old stones are worn but still faintly legible.', 'The air is colder here than in the surrounding woods.', 'Faint tracks, both human and not, cross each other near the outer walls.'], 'notable_features': ['A collapsed central hall with a stairway leading down into the dark.', "A ring of standing stones just outside the ruin's main walls.", 'Recently disturbed ground that suggests someone has been digging.'], 'relevant_facts': ['The ruins predate Oakshade and the fallen kingdom that once ruled the Vale.', 'Relics taken from the ruins are considered bad luck by most villagers.', 'The Ashen Band is believed to camp nearby and use the ruins as a staging ground.', 'Restless spirits are most active after dusk.'], 'active_rumors': ['Something old has been waking up beneath the ruins.', 'A member of the Ashen Band was found dead near the standing stones, untouched by weapons.', 'The Village Council is considering hiring outside help to investigate the ruins quietly.']}], 'factions': [{'name': 'Village Council', 'description': 'Local leaders trying to keep Oakshade safe.'}, {'name': 'Ashen Band', 'description': 'A loose group of raiders and scavengers operating near the ruins.'}]}
# {'npcs': [{'id': 'mara_innkeeper', 'name': 'Mara', 'location': 'oakshade_village', 'role': 'Innkeeper of the Oakshade inn and informal voice of the Village Council', 'personality': ['observant', 'practical', 'protective of regulars', 'slow to trust strangers'], 'goals': ["Keep Oakshade's travelers safe and paying", 'Find out what is happening near the Emberwood Ruins', 'Avoid open conflict with the Ashen Band while the Council figures out what to do'], 'disposition': 'wary but fair', 'knowledge': ['Knows most villagers by name and tracks who is missing and who is back.', 'Heard that a Council scout has not returned from a trip toward the ruins.', 'Does not trust the hooded traveler Corvin and has noticed he watches newcomers.', 'Knows the blacksmith, Harlan, has been buying strange metal from travelers.'], 'relationship_summary': 'Has never met the player before. Treats outsiders politely but guardedly until they prove themselves.'}, {'id': 'corvin_stranger', 'name': 'Corvin', 'location': 'oakshade_village', 'role': 'Hooded traveler at the inn; possible scout or informant with his own agenda', 'personality': ['quiet', 'guarded', 'quick to size people up', 'willing to pay for discreet help'], 'goals': ['Find out what the Ashen Band is pulling out of the Emberwood Ruins', 'Avoid being identified by the Village Council', 'Recruit an outsider to do the dangerous part of his investigation'], 'disposition': 'neutral, attentive, hopeful when approached quietly', 'knowledge': ['Claims to have followed the Ashen Band for weeks before coming to Oakshade.', 'Has a partial map of the Emberwood Ruins he is willing to share for a price.', "Will not speak openly in Mara's presence and prefers conversations away from the bar.", 'Knows the Council has lost at least one scout but has not told anyone in the village.'], 'relationship_summary': 'Has been watching the player since they walked in. Will approach if the player seems capable and discreet.'}, {'id': 'harlan_smith', 'name': 'Harlan', 'location': 'oakshade_village', 'role': 'Village blacksmith and reluctant middleman for outside traders', 'personality': ['blunt', 'anxious', 'loyal to the village but short on money', 'slow to lie but quick to change the subject'], 'goals': ['Keep his forge running through a bad season', 'Avoid being blamed for buying metal that might have come from the ruins', 'Protect his family from anything that looks like Ashen Band trouble'], 'disposition': 'nervous but approachable', 'knowledge': ['Has been buying unusual metal from passing travelers at a suspicious discount.', 'Suspects but will not admit that some of it came from the Emberwood Ruins.', 'Knows the Ashen Band has used at least one of his buyers as a courier.', 'Will sell basic gear to the player and trade information if pressed gently.'], 'relationship_summary': 'Treats the player as a potential customer first. Will open up only if the player does not threaten his livelihood.'}]}
# {'quests': [{'id': 'missing_scout', 'name': 'The Missing Scout', 'status': 'not_started', 'giver': 'mara_innkeeper', 'location_id': 'oakshade_village', 'summary': 'The Village Council sent a scout toward the Emberwood Ruins to investigate reports of Ashen Band activity. The scout has not returned. Mara, the innkeeper, is quietly asking travelers if anyone would be willing to look into it.', 'short_summary': "Find out what happened to the Council's missing scout near the Emberwood Ruins.", 'objectives': [{'id': 'speak_to_mara', 'description': 'Speak with Mara at the inn and agree to help look into the missing scout.', 'completed': False}, {'id': 'gather_information', 'description': "Gather information about the Ashen Band or the scout's route from villagers or travelers.", 'completed': False}, {'id': 'search_emberwood_ruins', 'description': "Travel to the Emberwood Ruins and search for evidence of the scout's fate.", 'completed': False}], 'branches': [{'branch_id': 'work_with_council', 'description': 'Report findings back to Mara and the Village Council. Gains village trust and backup, but loses the chance to keep any ruin-relics.', 'status': 'available'}, {'branch_id': 'work_with_corvin', 'description': "Accept Corvin's offer and investigate quietly on his terms. Gains the map fragment and potential payment, but risks the Council seeing you as aligned with outsiders.", 'status': 'available'}, {'branch_id': 'confront_ashen_band', 'description': 'Directly confront the Ashen Band about the scout. High risk, high reward.', 'status': 'locked', 'unlock_condition': "Learn the Ashen Band's location from Corvin, Harlan, or evidence at the ruins."}], 'proposed_rewards': ['Payment from the Village Council if the Council branch is taken', 'Partial map of the Emberwood Ruins if the Corvin branch is taken', 'Increased standing with either the Village Council or Corvin depending on branch']}]}

# %%
from src.router import classify_route

state = build_initial_state(
    session_id="demo_session_001",
    player_action="I ask the innkeeper what she knows about the missing caravan."
)

decision = classify_route(state.turn.player_action, state)
decision
# Out:
# RouteDecision(route='mixed_action', next_nodes=['npc_agent', 'quest_agent'], reason='Player action combines conversation with quest-related intent.')

# %%
tests = [
    "I ask the innkeeper what she knows about the missing caravan.",
    "I explore the ruins and search for tracks.",
    "I attack the bandit with my sword.",
    "What do I know about the history of these ruins?",
    "I question Tomas about the quest reward.",
]

for action in tests:
    decision = classify_route(action, state)
    print(action)
    print(decision.model_dump())
    print("-" * 60)
# Out:
# I ask the innkeeper what she knows about the missing caravan.
# {'route': 'mixed_action', 'next_nodes': ['npc_agent', 'quest_agent'], 'reason': 'Player action combines conversation with quest-related intent.'}
# ------------------------------------------------------------
# I explore the ruins and search for tracks.
# {'route': 'exploration', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to focus on movement, searching, or environment interaction.'}
# ------------------------------------------------------------
# I attack the bandit with my sword.
# {'route': 'combat', 'next_nodes': ['rules_agent'], 'reason': 'Player action contains combat-oriented language.'}
# ------------------------------------------------------------
# What do I know about the history of these ruins?
# {'route': 'lore_query', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to request world or setting knowledge.'}
# ------------------------------------------------------------
# I question Tomas about the quest reward.
# {'route': 'mixed_action', 'next_nodes': ['npc_agent', 'quest_agent'], 'reason': 'Player action combines conversation with quest-related intent.'}
# ------------------------------------------------------------

# %%
extra_tests = [
    "I go north.",
    "I talk to Marla.",
    "I inspect the wagon.",
    "I defend myself from the wolf.",
    "Tell me about the Ashen Band.",
    "I report back to Tomas.",
]

for action in extra_tests:
    decision = classify_route(action, state)
    print(action)
    print(decision.model_dump())
    print("-" * 60)
# Out:
# I go north.
# {'route': 'exploration', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to focus on movement, searching, or environment interaction.'}
# ------------------------------------------------------------
# I talk to Marla.
# {'route': 'dialogue', 'next_nodes': ['npc_agent'], 'reason': 'Player action appears to be directed at a character or conversation.'}
# ------------------------------------------------------------
# I inspect the wagon.
# {'route': 'exploration', 'next_nodes': ['lore_agent'], 'reason': 'Player action appears to focus on movement, searching, or environment interaction.'}
# ------------------------------------------------------------
# I defend myself from the wolf.
# {'route': 'combat', 'next_nodes': ['rules_agent'], 'reason': 'Player action contains combat-oriented language.'}
# ------------------------------------------------------------
# Tell me about the Ashen Band.
# {'route': 'dialogue', 'next_nodes': ['npc_agent'], 'reason': 'Player action appears to be directed at a character or conversation.'}
# ------------------------------------------------------------
# I report back to Tomas.
# {'route': 'quest_progression', 'next_nodes': ['quest_agent'], 'reason': 'Player action appears tied to a quest objective or mission progress.'}
# ------------------------------------------------------------

# %%
from src.state_manager import build_initial_state
from src.orchestrator import run_turn

# %%
state = build_initial_state(
    session_id="demo_session_001",
    player_action="The player enters the world."
)

# %%
result = run_turn(
    state,
    "I ask the innkeeper what she knows about the missing caravan."
)

result
# Out:
# OrchestrationResult(player_action='I ask the innkeeper what she knows about the missing caravan.', selected_route='mixed_action', next_nodes=['npc_agent', 'quest_agent'], execution_plan=['npc_agent', 'quest_agent'], execution_results=[NodeExecutionResult(node_name='npc_agent', status='completed', summary='Placeholder execution completed for npc_agent.', attempts=1), NodeExecutionResult(node_name='quest_agent', status='completed', summary='Placeholder execution completed for quest_agent.', attempts=1)], reason='Player action combines conversation with quest-related intent.', aborted=False, abort_reason=None, state=GameState(canonical=CanonicalGameState(current_scene='The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.', location='Oakshade Village', active_quests=[QuestState(quest_id='missing_scout', name='The Missing Scout', status='not_started', objectives=[QuestObjective(objective_id='speak_to_mara', description='Speak with Mara at the inn and agree to help look into the missing scout.', completed=False), QuestObjective(objective_id='gather_information', description="Gather information about the Ashen Band or the scout's route from villagers or travelers.", completed=False), QuestObjective(objective_id='search_emberwood_ruins', description="Travel to the Emberwood Ruins and search for evidence of the scout's fate.", completed=False)], quest_giver_id='mara_innkeeper')], npc_states={'mara_innkeeper': NPCState(npc_id='mara_innkeeper', name='Mara', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=["Keep Oakshade's travelers safe and paying", 'Find out what is happening near the Emberwood Ruins', 'Avoid open conflict with the Ashen Band while the Council figures out what to do']), 'corvin_stranger': NPCState(npc_id='corvin_stranger', name='Corvin', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['Find out what the Ashen Band is pulling out of the Emberwood Ruins', 'Avoid being identified by the Village Council', 'Recruit an outsider to do the dangerous part of his investigation']), 'harlan_smith': NPCState(npc_id='harlan_smith', name='Harlan', location='oakshade_village', disposition='neutral', last_interaction_summary=None, known_facts=[], goals=['Keep his forge running through a bad season', 'Avoid being blamed for buying metal that might have come from the ruins', 'Protect his family from anything that looks like Ashen Band trouble'])}, inventory=[], party_status=PartyStatus(hp=20, max_hp=20, conditions=[], gold=0), recent_events=[EventRecord(event_type='session_start', summary='Session initialized in Oakshade Village.', source_node='state_manager')]), turn=TransientTurnState(player_action='I ask the innkeeper what she knows about the missing caravan.', selected_route='mixed_action', specialist_outputs=[], proposed_updates=[], validation_status='pending', current_turn_events=[EventRecord(event_type='route_selected', summary="Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].", source_node='orchestrator'), EventRecord(event_type='route_reason', summary='Player action combines conversation with quest-related intent.', source_node='router'), EventRecord(event_type='execution_plan_built', summary="Execution plan created: ['npc_agent', 'quest_agent']", source_node='orchestrator'), EventRecord(event_type='node_executed', summary='npc_agent executed with placeholder behavior.', source_node='orchestrator'), EventRecord(event_type='node_executed', summary='quest_agent executed with placeholder behavior.', source_node='orchestrator')], final_response=None), meta=SessionExecutionMetadata(turn_id=2, session_id='demo_session_001', timestamp='2026-04-24T16:39:09.844888+00:00', retry_count=0, max_retries=3)))

# %%
import json
print(json.dumps(result.model_dump(), indent=2))
# Out:
# {
#   "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#   "selected_route": "mixed_action",
#   "next_nodes": [
#     "npc_agent",
#     "quest_agent"
#   ],
#   "execution_plan": [
#     "npc_agent",
#     "quest_agent"
#   ],
#   "execution_results": [
#     {
#       "node_name": "npc_agent",
#       "status": "completed",
#       "summary": "Placeholder execution completed for npc_agent.",
#       "attempts": 1
#     },
#     {
#       "node_name": "quest_agent",
#       "status": "completed",
#       "summary": "Placeholder execution completed for quest_agent.",
#       "attempts": 1
#     }
#   ],
#   "reason": "Player action combines conversation with quest-related intent.",
#   "aborted": false,
#   "abort_reason": null,
#   "state": {
#     "canonical": {
#       "current_scene": "The player arrives at Oakshade Village, where rumors, danger, and opportunity are beginning to converge.",
#       "location": "Oakshade Village",
#       "active_quests": [
#         {
#           "quest_id": "missing_scout",
#           "name": "The Missing Scout",
#           "status": "not_started",
#           "objectives": [
#             {
#               "objective_id": "speak_to_mara",
#               "description": "Speak with Mara at the inn and agree to help look into the missing scout.",
#               "completed": false
#             },
#             {
#               "objective_id": "gather_information",
#               "description": "Gather information about the Ashen Band or the scout's route from villagers or travelers.",
#               "completed": false
#             },
#             {
#               "objective_id": "search_emberwood_ruins",
#               "description": "Travel to the Emberwood Ruins and search for evidence of the scout's fate.",
#               "completed": false
#             }
#           ],
#           "quest_giver_id": "mara_innkeeper"
#         }
#       ],
#       "npc_states": {
#         "mara_innkeeper": {
#           "npc_id": "mara_innkeeper",
#           "name": "Mara",
#           "location": "oakshade_village",
#           "disposition": "neutral",
#           "last_interaction_summary": null,
#           "known_facts": [],
#           "goals": [
#             "Keep Oakshade's travelers safe and paying",
#             "Find out what is happening near the Emberwood Ruins",
#             "Avoid open conflict with the Ashen Band while the Council figures out what to do"
#           ]
#         },
#         "corvin_stranger": {
#           "npc_id": "corvin_stranger",
#           "name": "Corvin",
#           "location": "oakshade_village",
#           "disposition": "neutral",
#           "last_interaction_summary": null,
#           "known_facts": [],
#           "goals": [
#             "Find out what the Ashen Band is pulling out of the Emberwood Ruins",
#             "Avoid being identified by the Village Council",
#             "Recruit an outsider to do the dangerous part of his investigation"
#           ]
#         },
#         "harlan_smith": {
#           "npc_id": "harlan_smith",
#           "name": "Harlan",
#           "location": "oakshade_village",
#           "disposition": "neutral",
#           "last_interaction_summary": null,
#           "known_facts": [],
#           "goals": [
#             "Keep his forge running through a bad season",
#             "Avoid being blamed for buying metal that might have come from the ruins",
#             "Protect his family from anything that looks like Ashen Band trouble"
#           ]
#         }
#       },
#       "inventory": [],
#       "party_status": {
#         "hp": 20,
#         "max_hp": 20,
#         "conditions": [],
#         "gold": 0
#       },
#       "recent_events": [
#         {
#           "event_type": "session_start",
#           "summary": "Session initialized in Oakshade Village.",
#           "source_node": "state_manager"
#         }
#       ]
#     },
#     "turn": {
#       "player_action": "I ask the innkeeper what she knows about the missing caravan.",
#       "selected_route": "mixed_action",
#       "specialist_outputs": [],
#       "proposed_updates": [],
#       "validation_status": "pending",
#       "current_turn_events": [
#         {
#           "event_type": "route_selected",
#           "summary": "Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].",
#           "source_node": "orchestrator"
#         },
#         {
#           "event_type": "route_reason",
#           "summary": "Player action combines conversation with quest-related intent.",
#           "source_node": "router"
#         },
#         {
#           "event_type": "execution_plan_built",
#           "summary": "Execution plan created: ['npc_agent', 'quest_agent']",
#           "source_node": "orchestrator"
#         },
#         {
#           "event_type": "node_executed",
#           "summary": "npc_agent executed with placeholder behavior.",
#           "source_node": "orchestrator"
#         },
#         {
#           "event_type": "node_executed",
#           "summary": "quest_agent executed with placeholder behavior.",
#           "source_node": "orchestrator"
#         }
#       ],
#       "final_response": null
#     },
#     "meta": {
#       "turn_id": 2,
#       "session_id": "demo_session_001",
#       "timestamp": "2026-04-24T16:39:09.844888+00:00",
#       "retry_count": 0,
#       "max_retries": 3
#     }
#   }
# }

# %%
print("Selected route:", result.selected_route)
print("Execution plan:", result.execution_plan)

for item in result.execution_results:
    print(item.model_dump())
# Out:
# Selected route: mixed_action
# Execution plan: ['npc_agent', 'quest_agent']
# {'node_name': 'npc_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for npc_agent.', 'attempts': 1}
# {'node_name': 'quest_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for quest_agent.', 'attempts': 1}

# %%
for event in result.state.turn.current_turn_events:
    print(event.model_dump())
# Out:
# {'event_type': 'route_selected', 'summary': "Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].", 'source_node': 'orchestrator'}
# {'event_type': 'route_reason', 'summary': 'Player action combines conversation with quest-related intent.', 'source_node': 'router'}
# {'event_type': 'execution_plan_built', 'summary': "Execution plan created: ['npc_agent', 'quest_agent']", 'source_node': 'orchestrator'}
# {'event_type': 'node_executed', 'summary': 'npc_agent executed with placeholder behavior.', 'source_node': 'orchestrator'}
# {'event_type': 'node_executed', 'summary': 'quest_agent executed with placeholder behavior.', 'source_node': 'orchestrator'}

# %%
from src.orchestrator import run_turn

state = build_initial_state(session_id="demo_session_001")

result = run_turn(
    state,
    "I ask the innkeeper what she knows about the missing caravan."
)

print("Aborted:", result.aborted)
print("Abort reason:", result.abort_reason)
for item in result.execution_results:
    print(item.model_dump())
# Out:
# Aborted: False
# Abort reason: None
# {'node_name': 'npc_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for npc_agent.', 'attempts': 1}
# {'node_name': 'quest_agent', 'status': 'completed', 'summary': 'Placeholder execution completed for quest_agent.', 'attempts': 1}

# %%
state = build_initial_state(session_id="demo_session_002")

failed_result = run_turn(
    state,
    "I ask the innkeeper what she knows about the missing caravan.",
    fail_nodes=["npc_agent"]
)

print("Aborted:", failed_result.aborted)
print("Abort reason:", failed_result.abort_reason)
for item in failed_result.execution_results:
    print(item.model_dump())
# Out:
# Aborted: True
# Abort reason: npc_agent exceeded max retries (3).
# {'node_name': 'npc_agent', 'status': 'failed', 'summary': 'npc_agent failed after 3 retries. Execution aborted.', 'attempts': 3}

# %%
for event in failed_result.state.turn.current_turn_events:
    print(event.model_dump())
# Out:
# {'event_type': 'route_selected', 'summary': "Route 'mixed_action' selected with nodes ['npc_agent', 'quest_agent'].", 'source_node': 'orchestrator'}
# {'event_type': 'route_reason', 'summary': 'Player action combines conversation with quest-related intent.', 'source_node': 'router'}
# {'event_type': 'execution_plan_built', 'summary': "Execution plan created: ['npc_agent', 'quest_agent']", 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 1. Retry count is now 1.', 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 2. Retry count is now 2.', 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 3. Retry count is now 3.', 'source_node': 'orchestrator'}
# {'event_type': 'node_retry', 'summary': 'npc_agent failed on attempt 4. Retry count is now 4.', 'source_node': 'orchestrator'}
# {'event_type': 'execution_aborted', 'summary': 'npc_agent exceeded max retries (3).', 'source_node': 'orchestrator'}

# %% [markdown]
# ## Test `lore_agent.py` and `npc_agent.py`

# %%
from src.agents.lore_agent import LoreAgentInput, run_lore_agent
from src.agents.npc_agent import NPCAgentInput, run_npc_agent

# %%
lore_input = LoreAgentInput(
    player_action="I explore the ruins and search for tracks.",
    current_scene="The player stands at the edge of Emberwood Ruins near broken stone walls.",
    location="Emberwood Ruins",
    world_summary="The Shattered Vale is an old frontier region filled with ruined sites, local rumors, and small settlements trying to survive.",
    relevant_facts=[
        "The Emberwood Ruins are rumored to be tied to recent disappearances.",
        "The village believes strange lights have been seen near the ruins at night.",
    ],
    active_quest_summaries=[
        "The Missing Caravan: investigate what happened near the ruins."
    ],
)

npc_input = NPCAgentInput(
    player_action="I ask the innkeeper what she knows about the missing caravan.",
    npc_name="Marla Thorn",
    npc_role="Innkeeper",
    npc_personality=["warm", "observant", "cautious"],
    npc_goals=["protect the village", "keep travelers safe"],
    npc_disposition="neutral",
    current_scene="The player is speaking with Marla inside the village inn.",
    relationship_summary="Marla does not know the player well yet.",
    relevant_memory=[
        "Marla has seen strange lights near the ruins.",
        "She is worried the missing caravan may mean trouble is getting closer to the village.",
    ],
)

# %%
lore_result = await run_lore_agent(lore_input)
npc_result = await run_npc_agent(npc_input)

print(lore_result.model_dump())
print(npc_result.model_dump())
# Out:
# {'summary': "The player explores the edge of Emberwood Ruins and searches for tracks. Given the ruin's connection to recent disappearances and strange lights, this is a meaningful investigative action. The broken stone walls provide natural cover and shadow zones that could obscure or preserve tracks depending on weather exposure. A careful search would likely yield physical evidence consistent with recent human or creature passage, reinforcing the active caravan investigation.", 'environmental_details': ['Broken stone walls create sheltered pockets where dirt and debris accumulate — good surfaces for preserving footprints.', 'The ground near the ruin threshold is likely a mix of cracked flagstone and disturbed earth, offering uneven tracking conditions.', 'Overgrown vegetation along the ruin perimeter may show signs of trampling or forced passage.', "Ash or charred debris consistent with the 'Emberwood' name may be present, potentially holding impressions well.", 'Low light near collapsed walls and rubble piles could conceal secondary evidence like dropped items or drag marks.'], 'lore_facts_used': ['Emberwood Ruins are rumored to be tied to recent disappearances in the region.', 'Strange lights have been reported near the ruins at night by village witnesses.', 'The Missing Caravan quest is actively tied to events near the ruins.', 'The Shattered Vale is a frontier region with ruined sites — ruins of this type typically show age, overgrowth, and structural decay, which affects how tracks are preserved.'], 'proposed_consequences': ['Player discovers tracks suggesting multiple humanoid figures entered the ruins recently — consistent with caravan personnel or those who intercepted them.', 'Tracks show an unusual pattern: some lead inward but none clearly lead back out, raising the stakes of the disappearances.', 'Disturbed ground near one wall segment hints at something heavy being dragged — possibly cargo or a body — deeper into the ruin interior.', "A faint scorch mark or residue near a collapsed archway may be loosely consistent with the 'strange lights' reported by villagers, suggesting the lights are not natural.", 'No hostile entities are immediately encountered, but evidence of recent habitation (ash pile, disturbed rubble) suggests the ruins are actively being used by someone or something.'], 'suggested_next_step': 'Follow the inward-leading tracks deeper into the ruins, or examine the scorch marks near the collapsed archway to determine the nature of the strange lights before proceeding further.'}
# {'speech': '*Marla pauses mid-wipe of the bar counter, glancing up at you with careful eyes before setting the rag down slowly.*\n\n"The Aldren caravan? Aye, I noticed when they didn\'t come through last Tenday. They\'re reliable folk — Bram Aldren\'s run that route for near on twelve years. Never missed a stop here." \n\n*She leans in slightly, lowering her voice.*\n\n"I haven\'t said this loud, mind you, but... three nights back I saw lights out near the old ruins on the eastern ridge. Strange, flickering things — not torchlight. Too still for that, but too... wrong for fireflies." \n\n*She straightens up, arms crossing, and her tone becomes measured.*\n\n"I don\'t know what\'s out there, and I won\'t pretend I do. But if that caravan went east along the ridge road — which they would have — then..." *She trails off, jaw tightening.* "You seem like someone who asks questions for a reason. Are you planning to go looking for them?"', 'emotional_tone': 'guarded warmth — she wants to help but is being careful about how much she reveals to a stranger, tinged with genuine worry', 'intent': "Marla is sharing what she knows in measured doses to gauge the player's trustworthiness and purpose. She is testing whether the player is a threat, a fool, or a genuine ally before committing to further cooperation. She wants to protect the village but won't hand information to just anyone.", 'proposed_social_consequences': ["If the player responds with honest concern for the caravan or the village, Marla's disposition shifts toward Friendly and she may share more specific details about the lights or the ridge road.", 'If the player seems mercenary or dismissive, Marla clams up — disposition drops to Unfavorable and future dialogue checks with her become harder.', 'If the player asks a thoughtful follow-up question, it could trigger a rumor hook or a soft quest nudge toward the eastern ruins.', 'Marla may quietly mention the player to the village elder or local guard, flagging them as a person of interest — either positively or negatively depending on how the conversation unfolds.'], 'suggested_next_step': "Present the player with a choice of how to answer Marla's closing question — their response will be the key trust-check moment that determines how cooperative she becomes going forward."}

# %% [markdown]
# ## Test `rules_agent.py`

# %%
from src.agents.rules_agent import RulesAgentInput, run_rules_agent

# %%
rules_input = RulesAgentInput(
    player_action="I attack the bandit with my sword.",
    current_scene="The player is facing a bandit on the road near Emberwood Ruins.",
    character_hp=20,
    character_max_hp=20,
    relevant_stats=["strength +2", "defense +1"],
    inventory=["sword", "torch"],
    rules_summary=(
        "Combat uses a lightweight resolution system. "
        "Most attacks are treated as a 1d20-style action against an easy, medium, or hard threshold. "
        "Success deals modest damage, partial success may involve tradeoffs, and failure may expose the player to retaliation. "
        "Typical damage ranges from 2 to 6."
    ),
    difficulty="medium",
    enemy_name="Bandit",
    enemy_hp=10,
)

# %%
rules_result = await run_rules_agent(rules_input)
print(rules_result.model_dump())
# Out:
# {'resolution_type': 'combat action', 'outcome': 'The player swings their sword at the bandit. Rolling against a medium difficulty threshold with a +2 strength modifier, the attack lands cleanly — a solid hit.', 'mechanical_summary': "Medium difficulty threshold (typically ~12 on a d20 scale). Player's +2 strength modifier improves the attack roll. Roll assumed successful (hit). Damage rolled in the 2–6 range: 4 base damage dealt to the bandit. No retaliation triggered on a clean success.", 'damage_dealt': 4, 'damage_taken': 0, 'status_effects': ['No new status effects applied'], 'proposed_state_changes': ['Bandit HP: 10 → 6', 'Player HP: unchanged at 20/20'], 'suggested_next_step': "Bandit is still alive at 6 HP and may retaliate on their turn. Narrator should describe the bandit's response and prompt the player for their next action."}

# %%
from src.agents.rules_agent import RulesAgentInput, run_rules_agent

test_input = RulesAgentInput(
    player_action="I attack the goblin with my sword",
    current_scene="A goblin blocks the narrow cave passage.",
    character_hp=20,
    character_max_hp=20,
    relevant_stats=["Strength +2"],
    inventory=["sword", "torch"],
    rules_summary="Use simple d10 resolution. High rolls succeed, middle rolls partially succeed, low rolls fail.",
    difficulty="medium",
    enemy_name="Goblin",
    enemy_hp=15,
)

result = await run_rules_agent(test_input)
result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.agents.rules_agent import RulesAgentInput, run_rules_agent
#       2
#       3 test_input = RulesAgentInput(
#       4     player_action="I attack the goblin with my sword",
#
# ModuleNotFoundError: No module named 'src'
